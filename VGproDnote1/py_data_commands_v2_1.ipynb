# %% [markdown]
# <h1>Vent Gates Analysis.</h1>

# %% [markdown]
# <h2> Abriendo archivo csv mes de Abril </h2>

# %%
import pandas as pd

# %%
df_seeing_vg= pd.read_csv('df2204.csv')

# %%
df_seeing_vg.describe()
# Out:
#         Unnamed: 0  VG_date_time_num  WindSpeed_mean      VG_East  \
# count  5724.000000      5.724000e+03     5724.000000  5724.000000
# mean   2862.500000      1.650508e+09        7.209207    22.913871
# std    1652.520802      6.144116e+05        3.267869    26.039233
# min       1.000000      1.648966e+09        0.000000     0.000000
# 25%    1431.750000      1.650431e+09        5.100000     0.000000
# 50%    2862.500000      1.650689e+09        7.200000    15.000000
# 75%    4293.250000      1.650875e+09        9.500000    30.000000
# max    5724.000000      1.651319e+09       16.900000   100.000000
#
#            VG_West  seeing_mean
# count  5724.000000  5724.000000
# mean     32.383823     0.903206
# std      31.025931     0.557370
# min       0.000000     0.160000
# 25%      10.000000     0.585000
# 50%      20.000000     0.744000
# 75%      50.000000     1.034000
# max     100.000000     6.704000

# %%
df_seeing_vg= df_seeing_vg.dropna()

# %%
df_seeing_vg
# Out:
#       Unnamed: 0  VG_date_time_num  WindSpeed_mean  VG_East  VG_West  \
# 0              1        1648965670             2.7       30       30
# 1              2        1648965703             2.7       30       30
# 2              3        1648965730             2.7       30       30
# 3              4        1648965760             2.7       30       30
# 4              5        1648965792             2.7       30       30
# ...          ...               ...             ...      ...      ...
# 5719        5720        1651318751             1.9        5       80
# 5720        5721        1651318781             1.9        5       80
# 5721        5722        1651318824             2.1        5       80
# 5722        5723        1651318862             2.1        5       80
# 5723        5724        1651318900             2.1        5       80
#
#       seeing_mean  VG_date
# 0           0.398   4/2/22
# 1           0.446   4/2/22
# 2           0.429   4/2/22
# 3           0.418   4/2/22
# 4           0.339   4/2/22
# ...           ...      ...
# 5719        3.741  4/30/22
# 5720        6.001  4/30/22
# 5721        4.896  4/30/22
# 5722        4.892  4/30/22
# 5723        3.577  4/30/22
#
# [5724 rows x 7 columns]

# %%
df_s_vge=df_seeing_vg.plot(kind='scatter', x='VG_East', y='seeing_mean')
# Out:
# /shared-libs/python3.9/py/lib/python3.9/site-packages/pandas/plotting/_matplotlib/core.py:1041: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
df_s_vgw=df_seeing_vg.plot(kind='scatter', x='VG_West', y='seeing_mean')

# %% [markdown]
# <h2> Barplot </h2>

# %%
df_bar_east= df_seeing_vg.hist(column= 'VG_East')

# %%
df_bar_west= df_seeing_vg.hist(column= 'VG_West')

# %% [markdown]
# <h2> Seeing mean and Wind </h2>

# %%
df_wind_seeing= df_seeing_vg.plot(kind='scatter', x='WindSpeed_mean', y='seeing_mean')

# %% [markdown]
# <h2> Regresión Lineal </h2>

# %%
# !pip install statsmodels==0.13.5
# Out:
# Collecting statsmodels==0.13.5
#   Downloading statsmodels-0.13.5-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 89.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from statsmodels==0.13.5) (1.23.4)
# Requirement already satisfied: packaging>=21.3 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from statsmodels==0.13.5) (21.3)
# Collecting patsy>=0.5.2
#   Downloading patsy-0.5.3-py2.py3-none-any.whl (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.8/233.8 KB 58.1 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.3 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from statsmodels==0.13.5) (1.9.3)
# Requirement already satisfied: pandas>=0.25 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from statsmodels==0.13.5) (1.2.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from packaging>=21.3->statsmodels==0.13.5) (3.0.9)
# Requirement already satisfied: pytz>=2017.3 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pandas>=0.25->statsmodels==0.13.5) (2022.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from pandas>=0.25->statsmodels==0.13.5) (2.8.2)
# Requirement already satisfied: six in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from patsy>=0.5.2->statsmodels==0.13.5) (1.16.0)
# Installing collected packages: patsy, statsmodels
# Successfully installed patsy-0.5.3 statsmodels-0.13.5
# WARNING: You are using pip version 22.0.4; however, version 23.0 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %%
import statsmodels.api as sm

# %%
df_seeing_vg
# Out:
#       Unnamed: 0  VG_date_time_num  WindSpeed_mean  VG_East  VG_West  \
# 0              1        1648965670             2.7       30       30
# 1              2        1648965703             2.7       30       30
# 2              3        1648965730             2.7       30       30
# 3              4        1648965760             2.7       30       30
# 4              5        1648965792             2.7       30       30
# ...          ...               ...             ...      ...      ...
# 5719        5720        1651318751             1.9        5       80
# 5720        5721        1651318781             1.9        5       80
# 5721        5722        1651318824             2.1        5       80
# 5722        5723        1651318862             2.1        5       80
# 5723        5724        1651318900             2.1        5       80
#
#       seeing_mean  VG_date
# 0           0.398   4/2/22
# 1           0.446   4/2/22
# 2           0.429   4/2/22
# 3           0.418   4/2/22
# 4           0.339   4/2/22
# ...           ...      ...
# 5719        3.741  4/30/22
# 5720        6.001  4/30/22
# 5721        4.896  4/30/22
# 5722        4.892  4/30/22
# 5723        3.577  4/30/22
#
# [5724 rows x 7 columns]

# %%
DeepnoteChart(df_seeing_vg, """{"layer":[{"layer":[{"mark":{"clip":true,"type":"bar","color":"#f58518","tooltip":true},"encoding":{"x":{"sort":null,"type":"quantitative","field":"VG_East","scale":{"type":"linear"},"stack":"zero"},"y":{"sort":null,"type":"quantitative","field":"Unnamed: 0","scale":{"type":"linear"},"stack":"zero","aggregate":"count"}}}]}],"title":"","config":{"legend":{}},"$schema":"https://vega.github.io/schema/vega-lite/v5.json","encoding":{}}""")

# %% [markdown]
# <h3>definir variables dependientes (y), y variables independientes (x)</h3>

# %%
y=df_seeing_vg['seeing_mean']
x=df_seeing_vg['WindSpeed_mean']

# %% [markdown]
# <h3>explorar dataset</h3>

# %%
df_seeing_vg.plot(kind='scatter', x='WindSpeed_mean',y='seeing_mean')
# Out:
# /shared-libs/python3.9/py/lib/python3.9/site-packages/pandas/plotting/_matplotlib/core.py:1041: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <AxesSubplot: xlabel='WindSpeed_mean', ylabel='seeing_mean'>

# %% [markdown]
# <h3> Agregar constante y ajustar modelo</h3>

# %%
x=sm.add_constant(x)
lm=sm.OLS(y,x).fit()

# %%
lm.predict(x)
# Out:
# 0       0.705057
# 1       0.705057
# 2       0.705057
# 3       0.705057
# 4       0.705057
#           ...
# 5719    0.669902
# 5720    0.669902
# 5721    0.678691
# 5722    0.678691
# 5723    0.678691
# Length: 5724, dtype: float64

# %% [markdown]
# <h3> La tabla de regresion</h3>

# %%
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            seeing_mean   R-squared:                       0.066
# Model:                            OLS   Adj. R-squared:                  0.066
# Method:                 Least Squares   F-statistic:                     406.8
# Date:                Sat, 04 Feb 2023   Prob (F-statistic):           1.86e-87
# Time:                        21:05:33   Log-Likelihood:                -4579.1
# No. Observations:                5724   AIC:                             9162.
# Df Residuals:                    5722   BIC:                             9176.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              0.5864      0.017     34.006      0.000       0.553       0.620
# WindSpeed_mean     0.0439      0.002     20.170      0.000       0.040       0.048
# ==============================================================================
# Omnibus:                     3955.613   Durbin-Watson:                   0.562
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            68268.415
# Skew:                           3.123   Prob(JB):                         0.00
# Kurtosis:                      18.724   Cond. No.                         19.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# <h3> Ecuacion de Regresion Lineal</h3>

# %%
#Coeficiente WindSpeed_mean: 0.0439
#Coeficiente Constante: 0.5864
#y=ax+b
y_pred= 0.0439*x['WindSpeed_mean']+0.5864

# %% [markdown]
# <h3> Graficar Regresion Lineal</h3>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#graficar los puntos
plt.figure(figsize=(9,4), tight_layout=True)
sns.scatterplot(x=x['WindSpeed_mean'],y=y)
#Graficar linea
sns.lineplot(x=x['WindSpeed_mean'],y=y_pred, color='red')
plt.ylabel('Seeing_mean')
plt.xlim(0)
plt.ylim(0)
plt.show()

# %%
import seaborn as sns

# %%
df_seeing_vg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5724 entries, 0 to 5723
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        5724 non-null   int64
#  1   VG_date_time_num  5724 non-null   int64
#  2   WindSpeed_mean    5724 non-null   float64
#  3   VG_East           5724 non-null   int64
#  4   VG_West           5724 non-null   int64
#  5   seeing_mean       5724 non-null   float64
#  6   VG_date           5724 non-null   object
# dtypes: float64(2), int64(4), object(1)
# memory usage: 486.8+ KB

# %%
sns.pairplot(df_seeing_vg)

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=b0825127-ce86-44b2-b15d-94f3297009dc' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
